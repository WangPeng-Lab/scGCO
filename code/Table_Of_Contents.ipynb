# %% [markdown]
# This capsule contains all of the analysis that went into the manuscript "Single-cell Graph Cuts Optimization(scGCO)"
#
# The manuscript and analysis are broken up into 5 parts:
#
# 1. Analysis of MouseOB data
#
# 2. Analysis of Breast_Cancer data
#
# 3. Analysis of MERFISH data
#
# 4. Analysis of seqFISH data
#
# 5. Benckmark of simulated data
#
# These sections are in turn broken up into subsections that preprocess the data, run the scGCO pipeline, and interpret the results to generate the figures and statistics reported in the manuscript.([FIG2_a_b_c_d](/code/analysis/FIG2_a_b_c_d.ipynb) , [FIG2_e_f](/code/analysis/FIG2_e_f.ipynb))
#
# Below is a table of contents containing links to the various notebooks where each of these steps is carried out.
#
# Part 0 Manuscript
#
# * [scGCO_tutorial](/code/Tutorial/scGCO_tutorial.ipynb)
#
#
# Part 1 MouseOB
#
# * [gen_Suppl_Fig1](/code/analysis/MouseOB/gen_Suppl_Fig1.ipynb)
# * [gen_Suppl_Fig2](/code/analysis/MouseOB/gen_Suppl_Fig2.ipynb)
# * [gen_Suppl_Fig6](/code/analysis/MouseOB/gen_Suppl_Fig6.ipynb)
#
#
# Part 2 Breast_Cancer
#
# * [gen_Layer2_Fig](/code/analysis/Breast_Cancer/gen_Layer2_Fig.ipynb)
# * [gen_Suppl_Fig10](/code/analysis/Breast_Cancer/gen_Suppl_Fig10.ipynb)
#
# Part 3 MERFISH
#
# * [gen_Suppl_Fig14](/code/analysis/MERFISH/gen_Suppl_Fig14.ipynb)
#
#
# Part 4 seqFISH
#
#
# Part 5 simulations
#
# * [scGCO_simulate_script.ipynb](/code/Simulation/Simulate_script/scGCO_simulate_script.ipynb)
# * [scGCO_simulate_500K_large.ipynb](/code/Simulation/Simulate_script/scGCO_simulate_500K_large.ipynb)
# * [scGCO_simulate_1M_large.ipynb](/code/Simulation/Simulate_script/scGCO_simulate_1M_large.ipynb)
# * [spatialDE_simulate_script.ipynb](/code/Simulation/Simulate_script/spatialDE_simulate_script.ipynb)
# * [Fig2g_Compare_memory_simulation_data](/code/Simulation/Fig2g_Compare_memory_simulation_data.ipynb)
# * [Fig2h_Compare_time_simulation_data](/code/Simulation/Fig2h_Compare_time_simulation_data.ipynb)
